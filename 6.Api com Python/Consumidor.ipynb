# %%
from kafka import KafkaConsumer as kc
consumidor = kc("mensagens", bootstrap_servers="127.0.0.1:9092",consumer_timeout_ms=1000, 
               group_id="consumidores")

# %%
for mensagem in consumidor:
    print("Topic: ", mensagem.topic)
    print("Partição ", mensagem.partition)
    print("Chave ", mensagem.key)
    print("Offset ", mensagem.offset)
    print("Mensagem ", mensagem.value)
    print("------------------")
# Out:
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 0'
# Offset  47
# Mensagem  b'Mensagem 0.591905 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 1'
# Offset  48
# Mensagem  b'Mensagem 0.699305 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 2'
# Offset  49
# Mensagem  b'Mensagem 0.089540 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 3'
# Offset  50
# Mensagem  b'Mensagem 0.313820 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 7'
# Offset  51
# Mensagem  b'Mensagem 0.319394 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 8'
# Offset  52
# Mensagem  b'Mensagem 0.883908 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 9'
# Offset  53
# Mensagem  b'Mensagem 0.313746 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 0'
# Offset  54
# Mensagem  b'Mensagem 0.145854 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 1'
# Offset  55
# Mensagem  b'Mensagem 0.377747 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 2'
# Offset  56
# Mensagem  b'Mensagem 0.357942 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 3'
# Offset  57
# Mensagem  b'Mensagem 0.460991 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 7'
# Offset  58
# Mensagem  b'Mensagem 0.378014 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 8'
# Offset  59
# Mensagem  b'Mensagem 0.319378 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 9'
# Offset  60
# Mensagem  b'Mensagem 0.931673 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 0'
# Offset  61
# Mensagem  b'Mensagem 0.428701 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 1'
# Offset  62
# Mensagem  b'Mensagem 0.076807 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 2'
# Offset  63
# Mensagem  b'Mensagem 0.763355 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 3'
# Offset  64
# Mensagem  b'Mensagem 0.717040 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 7'
# Offset  65
# Mensagem  b'Mensagem 0.423985 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 8'
# Offset  66
# Mensagem  b'Mensagem 0.957900 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 9'
# Offset  67
# Mensagem  b'Mensagem 0.539336 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 0'
# Offset  68
# Mensagem  b'Mensagem 0.899025 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 1'
# Offset  69
# Mensagem  b'Mensagem 0.695118 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 2'
# Offset  70
# Mensagem  b'Mensagem 0.741807 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 3'
# Offset  71
# Mensagem  b'Mensagem 0.314364 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 7'
# Offset  72
# Mensagem  b'Mensagem 0.419510 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 8'
# Offset  73
# Mensagem  b'Mensagem 0.348054 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 9'
# Offset  74
# Mensagem  b'Mensagem 0.477855 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 0'
# Offset  75
# Mensagem  b'Mensagem 0.638107 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 1'
# Offset  76
# Mensagem  b'Mensagem 0.537165 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 2'
# Offset  77
# Mensagem  b'Mensagem 0.519633 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 3'
# Offset  78
# Mensagem  b'Mensagem 0.156416 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 7'
# Offset  79
# Mensagem  b'Mensagem 0.438997 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 8'
# Offset  80
# Mensagem  b'Mensagem 0.008932 '
# ------------------
# Topic:  mensagens
# Partição  2
# Chave  b'Chave 9'
# Offset  81
# Mensagem  b'Mensagem 0.049676 '
# ------------------
